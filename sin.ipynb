# %% [markdown]
# <a href="https://colab.research.google.com/github/puzlike/expert-octo-telegram/blob/main/sin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def my_function(X) :
    return np.sin(x * np.pi)

x = np.linspace (-5, 6, 1000)
plt. figure(figsize = (20, 6))
plt.plot(x, my_function (x))
plt.grid(True)

plt.xlabel('x')
plt.ylabel('my_function(x) ')
# Out:
# Text(0, 0.5, 'my_function(x) ')
