# %% [markdown]
# <a href="https://colab.research.google.com/github/puzlike/expert-octo-telegram/blob/main/Two_line_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install japanize-matplotlib | tail -n 1

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib

month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Ang', 'Sep', 'Oct', 'Nov', 'Dec']
tokyo = [6.1, 7.2, 10.1, 15.4, 20.2, 22.4, 25.4, 27.1, 24.4, 18.7, 11.4, 8.9]
okinawa = [17.4, 16.9, 18.7, 23.0, 25.7, 28.4, 29.8, 29.5, 28.4, 27.7, 23.2, 20.5]

plt.plot(month, tokyo, label='東京')
plt.plot(month, okinawa, label='沖縄')
plt.legend()
plt.title('平均気温')
plt.xlabel('月')
plt.ylabel('気温')
plt.show()
