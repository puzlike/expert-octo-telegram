# %% [markdown]
# <a href="https://colab.research.google.com/github/puzlike/expert-octo-telegram/blob/main/2ji_kansuu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 100)
a = 1
b = 1
c = 1
y = a * x**2 + b * x + c

plt.plot(x, y)
plt.grid()
plt.show()

# %%
x1 = -b / (2 * a)
y1 = c - b**2 / (4 * a)
print('頂点の座標 : ','x=',x1,' y=',y1)
# Out:
# 頂点の座標 :  x= -0.5  y= 0.75
